# %%
import pandas as pd

# %%
dados = pd.read_csv("data_predicted.csv")

# %%
dados.head()
# Out:
#    Unnamed: 0                                                 ID        DATA  \
# 0           0  pessoa-especialista-inteligencia-growth-at-bp-...  2023-10-20
# 1           1  cientista-de-dados-sr-at-genial-investimentos-...  2023-10-20
# 2           2  analista-de-planejamento-pl-at-harpia-human-ca...  2023-10-20
# 3           3  intelig%C3%AAncia-de-mercado-at-hecke-import-3...  2023-10-20
# 4           4  consultor-de-automa%C3%A7%C3%A3o-at-v-tal-3742...  2023-10-20
#
#                                     TITULO  \
# 0  PESSOA ESPECIALISTA INTELIGENCIA GROWTH
# 1                    Cientista de Dados Sr
# 2              Analista de Planejamento PL
# 3                  Inteligência de mercado
# 4                   Consultor de Automação
#
#                                        EMPRESA               LOCAL  \
# 0  BP - A Beneficência Portuguesa de São Paulo       São Paulo, SP
# 1                         Genial Investimentos       São Paulo, SP
# ...

# %%
len(dados)
# Out:
# 47

# %%
dados_predicted = pd.read_csv("data_predicted.csv")

# %%
dados_predicted
# Out:
#                                                   ID        DATA  \
# 0  cientista-de-dados-s%C3%AAnior-especialista-at...  2023-11-07
# 1  analista-de-projetos-remoto-at-indicium-375165...  2023-11-07
# 2  profissional-cientista-de-dados-s%C3%AAnior-at...  2023-11-07
# 3  cientista-de-dados-s%C3%AAnior-deep-learning-a...  2023-11-07
# 4  cientista-de-dados-s%C3%AAnior-especialista-at...  2023-11-07
# 5   machine-learning-architect-at-caylent-3727849925  2023-11-07
# 6  analista-de-crm-salesforce-marketing-cloud-at-...  2023-11-07
# 7  ai-product-manager-bootcamp-and-project-work-a...  2023-11-07
# 8  ai-product-manager-bootcamp-and-project-work-a...  2023-11-07
#
#                                           TITULO                EMPRESA  \
# 0      Cientista de Dados - Sênior /Especialista                 Dattos
# 1                  Analista de Projetos (Remoto)               Indicium
# 2         Profissional Cientista de Dados Sênior  BRQ Digital Solutions
# ...

# %%
df = pd.read_csv("data/newly_fetched_data.csv")

# %%
df
# Out:
#                                                     ID        DATA  \
# 0    cientista-de-dados-s%C3%AAnior-especialista-at...  2023-11-07
# 1    analista-de-projetos-remoto-at-indicium-375165...  2023-11-07
# 2    profissional-cientista-de-dados-s%C3%AAnior-at...  2023-11-07
# 3    cientista-de-dados-s%C3%AAnior-deep-learning-a...  2023-11-07
# 4    cientista-de-dados-s%C3%AAnior-especialista-at...  2023-11-07
# ..                                                 ...         ...
# 97                 developer-ios-sr-at-ci-t-3760431558  2023-11-07
# 98     senior-developer-java-brazil-at-ci-t-3741509851  2023-11-07
# 99     senior-java-developer-brazil-at-ci-t-3760432298  2023-11-07
# 100  pessoa-desenvolvedora-php-s%C3%AAnior-at-inter...  2023-11-07
# 101  part-time-personalized-internet-ads-assessor-j...  2023-11-07
#
#                                                 TITULO  \
# 0            Cientista de Dados - Sênior /Especialista
# ...
